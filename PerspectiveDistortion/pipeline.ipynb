# %%
import sys
import subprocess
import os

sys.path.append("..")
from framework import perspective_pipe

# %%
verbose = 1

# %%
# full_file_path = "/home/avk/study/1C/Diplom/PerspectiveDistortion/SampleData/IMG_20190317_170456.jpg"
# data_path = "/home/avk/study/1C/Diplom/BinarizationAndMetrics/examples/candidates/"

# %%
# for file_num, filename in enumerate(os.listdir(data_path)):
#     print()
#     print("Processing file #", file_num)
#     full_file_path = os.path.join(data_path, filename)
    
#     # perspective
#     perspective_pipe.process_file(full_file_path, verbose=verbose)
    
#     # 
    
#     process = subprocess.run(["mkdir", f"./for_metrics/example{file_num}"])
#     subprocess.call(f"mv *.jpg ./for_metrics/example{file_num}", shell=True)
# #     if file_num == 0:
# #         break

# %%
# for i in range(40):
#     dir_path = f"./appendixA/good/example{i}/"
#     full_file_path = os.path.join(dir_path, "0.jpg")
    
#     print()
#     print("Processing example #", i)
    
#     if not os.path.isdir(dir_path):
#         continue
    
#     # perspective
#     perspective_pipe.process_file(full_file_path, verbose=verbose)
    
#     # 
    
# #     process = subprocess.run(["mkdir", f"./for_metrics/example{file_num}"])
#     subprocess.call(f"mv *.jpg {dir_path}", shell=True)
# Out:
# Processing example # 0
#
# Processing example # 1
# For CannyEdgeDetection 0 channel of image was chosen
# Number of detected lines  4
# 0.5027932960893821 34.53446553446554
# -0.5027932960893948 263.7632367632368
# 90.0 33.533466533466594
# -88.99441340782121 -360.86013986013984
# mode == naive
# 1.4070138150903295
# mode == habr
# 1.423529411764706
# mode == zhang
# 0.985276692217038 0.9746829752320888
# hight / width: 1.4115929627999508
# width / hight: 0.7084195135235445
# (1327, 940, 3) 1.4117021276595745
#
# Processing example # 2
# For CannyEdgeDetection 0 channel of image was chosen
# Number of detected lines  4
# -7.541899441340782 238.73826173826183
# 8.547486033519547 74.57442557442562
# 90.0 56.55644355644358
# -88.99441340782121 -334.8341658341658
# mode == naive
# 1.0835734870317002
# mode == habr
# 1.4926553672316385
# mode == zhang
# 0.9876879256289233 0.694400994528726
# hight / width: 1.3977551698822779
# width / hight: 0.7154328751895959
# ...

# %%
for i in range(1):
    dir_path = "./problem/"
    full_file_path = os.path.join(dir_path, "0.jpg")
    
    print()
    print("Processing example #", i)
    
    if not os.path.isdir(dir_path):
        continue
    
    # perspective
    perspective_pipe.process_file(full_file_path, verbose=verbose)
    
    # 
    
#     process = subprocess.run(["mkdir", f"./for_metrics/example{file_num}"])
    subprocess.call(f"mv *.jpg {dir_path}", shell=True)
# Out:
# Processing example # 0
# For CannyEdgeDetection greyscale image was chosen
# Number of detected lines  4
# -0.5027932960893948 264.7642357642359
# 4.525139664804464 45.54545454545462
# -85.97765363128492 -353.8531468531469
# 90.0 24.52447552447552
# mode == naive
# 1.3953858392999205
# mode == habr
# 1.5022736668044647
# mode == zhang
# 0.9543684466945823 0.8843949668254425
# hight / width: 1.448068741086712
# width / hight: 0.6905749510548401
# (3639, 2513, 3) 1.4480700358137684
