# %%
# Be sure, that you are using python2
import garbage
import os
import numpy as np
import cv2
from matplotlib import pyplot as plt
# %matplotlib inline
import sys

# %%
sys.path.append("..")
# from framework import perspective_transform
from framework import visualize

# %%
data_path = "/home/avk/study/1C/Diplom/data/source2"

# %%
for file_num, filename in enumerate(os.listdir(data_path)):
    full_file_path = os.path.join(data_path, filename)
    if file_num == 0:
#     if file_num == 2:
        break
file_num, filename
# Out:
# (0, 'other_241.png')

# %%
initial_image = cv2.imread(full_file_path)
visualize.visualize_image(initial_image, inplace=True)

# %%
grey_image = cv2.cvtColor(initial_image, cv2.COLOR_BGR2GRAY)
visualize.visualize_image(grey_image, inplace=True)

# %%
distorted_image = garbage.geometric_transform(initial_image)
visualize.visualize_image(distorted_image, inplace=True)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-7-9b2631b5f915> in <module>()
# ----> 1 distorted_image = garbage.geometric_transform(initial_image)
#       2 visualize.visualize_image(distorted_image, inplace=True)
#
# /home/avk/study/1C/Diplom/DistortionTool/garbage.so in garbage.geometric_transform()
#
# TypeError: geometric_transform() takes at least 2 positional arguments (1 given)

# %%
distorted_image = garbage.darken(grey_image, 5)
visualize.visualize_image(distorted_image, inplace=True)

# %%
distorted_image = garbage.knock_out(grey_image, garbage.get_knock_scale())
visualize.visualize_image(distorted_image, inplace=True)

# %%
distorted_image = garbage.blur(initial_image, (39, 39))
visualize.visualize_image(distorted_image, inplace=True)

# %%
# distorted_image = garbage.rescale(grey_image, coef=1)
# visualize.visualize_image(distorted_image, inplace=True)

# %%
distorted_image = garbage.motion_blur(initial_image, (15, 15))
visualize.visualize_image(distorted_image, inplace=True)

# %%
distorted_image = garbage.sharpen(initial_image)
visualize.visualize_image(distorted_image, inplace=True)

# %%
distorted_image = garbage.add_gradient(initial_image)
visualize.visualize_image(distorted_image, inplace=True)

# %%
distorted_image = garbage.add_glares(initial_image, number_of_glares=40)
visualize.visualize_image(distorted_image, inplace=True)

# %%
# distorted_image = garbage.add_lines(initial_image, (1000, 1000), prob=1)
# visualize.visualize_image(distorted_image, inplace=True)

# %%
# distorted_image = garbage.spoil(grey_image)
# visualize.visualize_image(distorted_image, inplace=True)

# %%
distorted_image = garbage.add_crease(initial_image)
visualize.visualize_image(distorted_image, inplace=True)

# %%
distorted_image = garbage.crease_transform(initial_image, width_range=(900, 1000))
visualize.visualize_image(distorted_image, inplace=True)

# %%
# distorted_image = garbage.projective_transform(initial_image, (1000, 1000))
# visualize.visualize_image(distorted_image, inplace=True)

# %%
distorted_image = garbage.partial_stretching(initial_image, vertical=True, rel_start=0, rel_end=1, coef=1.5)
show_image(distorted_image)

# %%
initial_image
