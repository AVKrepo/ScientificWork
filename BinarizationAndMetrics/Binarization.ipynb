# %%
import subprocess
from matplotlib import pyplot as plt
# %matplotlib inline
import pytesseract
from PIL import Image

# %%
def binarize(input_file_path, output_file_path):
    process = subprocess.run(['./binarizewolfjolion', input_file_path, output_file_path])
    return Image.open(output_file_path)

# %%
bin_image = binarize("sample.jpg", "output.jpg")
bin_image
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=L size=800x271 at 0x7F67CFD6EA58>

# %%
pytesseract.image_to_string(bin_image)
# Out:
# ''

# %%
pytesseract.image_to_string(Image.open("sample.jpg"))
# Out:
# ''
